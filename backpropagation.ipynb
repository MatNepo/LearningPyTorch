# %%
# imports

import torch
from IPython.display import Image

# %% [markdown]
# Concept of chain rule for backpropagation

# %%
image_path = 'data/backpropagation_1.png'
Image(filename=image_path)

# %%
image_path = 'data/backpropagation_2.png'
Image(filename=image_path)

# %% [markdown]
# ## Computational graph
#
# We can get local gradians to get the chain rule to reach final value.
# Loss function is calculated due to the weights which we calculate for local parameters
